# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:passwordlocalhost:3306/united_nations

# %%
#This tells the SQL extension to use an alternative table format that still exists:
#the secret handshake to get the classic look back without prettytable throwing a tantrum.
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %%
# %%sql
# SELECT *
# FROM
#     geographic_location;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# (pymysql.err.ProgrammingError) (1146, "Table 'united_nations.geographic_location' doesn't exist")
# [SQL: SELECT *
# FROM
#     geographic_location;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
#
# SELECT
# 	loc.Country_name
# FROM
# 	united_nations.Geographic_Location AS loc
# WHERE REGION LIKE '%Central and Southern Asia%';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# (pymysql.err.ProgrammingError) (1146, "Table 'united_nations.geographic_location' doesn't exist")
# [SQL: SELECT
# 	loc.Country_name
# FROM
# 	united_nations.Geographic_Location AS loc
# WHERE REGION LIKE '%%Central and Southern Asia%%';]
# (Background on this error at: https://sqlalche.me/e/20/f405)
